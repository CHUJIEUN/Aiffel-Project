# %% [markdown]
# ### Exploration9. 폐렴 진단과 성능 개선

# %% [markdown]
# > 폐렴을 진단해보자

# %%
# 라이브러리 import

import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings(action='ignore')

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미합니다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 16
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %%
# 데이터 가져오기

train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %% [markdown]
# train 안에는 5216개, test 안에는 624개, val 안에는 16개가 있습니다.

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %% [markdown]
# 이제 train은 4185개, test는 624개, val은 1047개가 되었습니다.

# %% [markdown]
# - 파일 경로에 NORMAL이 있는지 확인하면 정상 이미지를 셀 수 있습니다.
# - 또한, 파일 경로에 PNEUMONIA이 있는지 확인하면 폐렴 이미지도 셀 수 있습니다.

# %%
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/NORMAL2-IM-1317-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person299_bacteria_1418.jpeg

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1072
# Pneumonia images count in training set: 3113

# %% [markdown]
# 정상보다 폐렴 이미지 수가 3배 더 많이 있습니다. 우리가 사용할 CNN 모델의 경우 데이터가 클래스별 balance가 좋을수록 training을 잘 합니다. 데이터가 클래스 불균형(imbalance)한 것은 차후에 조정할 예정입니다.

# %%
# tf.data 인스턴스를 만들어 봅시다.

train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
# Train 데이터셋, validation 데이터셋 개수 확인

TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %% [markdown]
# 현재 이미지에는 라벨 데이터가 따로 없습니다.
# 파일 경로에 'NORMAL'이나 'PNEUMONIA'가 포함되어 있기 때문에 이를 이용해서 라벨 데이터를 만들어 주는 함수를 만들어 보겠습니다.

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %% [markdown]
# - 이미지의 사이즈를 통일 시키고 GPU 메모리를 더욱 효율적으로 사용하기 위해 이미지 사이즈를 줄여봅시다.

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
# train 데이터 셋과 validation 데이터 셋을 만듭니다.

train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
# 이미지 리사이즈, 라벨이 잘 들어가 있는지 확인

for image, label in train_ds.take(1): #하나의 데이터만 가져온다는 의미
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
# test 데이터셋 만들기, 데이터 개수 확인

test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# - 데이터 시각화

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(4,math.ceil(BATCH_SIZE/4),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# - CNN 모델링

# %%
# 먼저, Convolution block을 만듭니다.

def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
# Dense Block 만들기

def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
#  - Weight balancing으로 데이터 imbalance 처리

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.95
# Weight for PNEUMONIA: 0.67

# %%
# 모델훈련

with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 87s 194ms/step - loss: 0.4436 - accuracy: 0.7711 - precision: 0.9400 - recall: 0.7399 - val_loss: 0.5807 - val_accuracy: 0.7346 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 50s 192ms/step - loss: 0.2480 - accuracy: 0.8987 - precision: 0.9695 - recall: 0.8917 - val_loss: 1.1631 - val_accuracy: 0.7385 - val_precision: 0.7385 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 50s 193ms/step - loss: 0.1933 - accuracy: 0.9260 - precision: 0.9785 - recall: 0.9208 - val_loss: 1.4517 - val_accuracy: 0.7337 - val_precision: 0.7337 - val_recall: 1.0000
# Epoch 4/25
# 261/261 [==============================] - 51s 197ms/step - loss: 0.1765 - accuracy: 0.9322 - precision: 0.9786 - recall: 0.9291 - val_loss: 0.1208 - val_accuracy: 0.9538 - val_precision: 0.9487 - val_recall: 0.9908
# Epoch 5/25
# 261/261 [==============================] - 52s 201ms/step - loss: 0.1731 - accuracy: 0.9322 - precision: 0.9764 - recall: 0.9314 - val_loss: 0.6001 - val_accuracy: 0.7798 - val_precision: 1.0000 - val_recall: 0.7010
# Epoch 6/25
# 261/261 [==============================] - 56s 215ms/step - loss: 0.1685 - accuracy: 0.9346 - precision: 0.9787 - recall: 0.9323 - val_loss: 0.1432 - val_accuracy: 0.9394 - val_precision: 0.9958 - val_recall: 0.9218
# Epoch 7/25
# 261/261 [==============================] - 48s 185ms/step - loss: 0.1315 - accuracy: 0.9454 - precision: 0.9868 - recall: 0.9391 - val_loss: 0.0886 - val_accuracy: 0.9625 - val_precision: 0.9892 - val_recall: 0.9595
# Epoch 8/25
# 261/261 [==============================] - 48s 185ms/step - loss: 0.1519 - accuracy: 0.9425 - precision: 0.9839 - recall: 0.9384 - val_loss: 0.0821 - val_accuracy: 0.9721 - val_precision: 0.9694 - val_recall: 0.9935
# Epoch 9/25
# 261/261 [==============================] - 46s 177ms/step - loss: 0.1432 - accuracy: 0.9449 - precision: 0.9845 - recall: 0.9408 - val_loss: 0.1229 - val_accuracy: 0.9587 - val_precision: 0.9945 - val_recall: 0.9490
# Epoch 10/25
# 261/261 [==============================] - 49s 188ms/step - loss: 0.1440 - accuracy: 0.9454 - precision: 0.9855 - recall: 0.9404 - val_loss: 0.2542 - val_accuracy: 0.8923 - val_precision: 1.0000 - val_recall: 0.8538
# Epoch 11/25
# 261/261 [==============================] - 48s 185ms/step - loss: 0.1066 - accuracy: 0.9583 - precision: 0.9919 - recall: 0.9517 - val_loss: 0.0714 - val_accuracy: 0.9808 - val_precision: 0.9770 - val_recall: 0.9974
# Epoch 12/25
# 261/261 [==============================] - 48s 186ms/step - loss: 0.1060 - accuracy: 0.9562 - precision: 0.9870 - recall: 0.9538 - val_loss: 0.0774 - val_accuracy: 0.9712 - val_precision: 0.9973 - val_recall: 0.9634
# Epoch 13/25
# 261/261 [==============================] - 48s 186ms/step - loss: 0.1127 - accuracy: 0.9557 - precision: 0.9880 - recall: 0.9520 - val_loss: 0.0856 - val_accuracy: 0.9779 - val_precision: 0.9868 - val_recall: 0.9830
# Epoch 14/25
# 261/261 [==============================] - 48s 186ms/step - loss: 0.1196 - accuracy: 0.9576 - precision: 0.9900 - recall: 0.9527 - val_loss: 0.1033 - val_accuracy: 0.9587 - val_precision: 0.9972 - val_recall: 0.9464
# Epoch 15/25
# 261/261 [==============================] - 48s 186ms/step - loss: 0.1108 - accuracy: 0.9607 - precision: 0.9893 - recall: 0.9574 - val_loss: 0.0980 - val_accuracy: 0.9606 - val_precision: 0.9548 - val_recall: 0.9935
# Epoch 16/25
# 261/261 [==============================] - 47s 181ms/step - loss: 0.0972 - accuracy: 0.9622 - precision: 0.9913 - recall: 0.9575 - val_loss: 0.5902 - val_accuracy: 0.7798 - val_precision: 0.7694 - val_recall: 1.0000
# Epoch 17/25
# 261/261 [==============================] - 48s 184ms/step - loss: 0.0928 - accuracy: 0.9686 - precision: 0.9911 - recall: 0.9664 - val_loss: 0.2268 - val_accuracy: 0.9183 - val_precision: 0.9985 - val_recall: 0.8901
# Epoch 18/25
# 261/261 [==============================] - 47s 182ms/step - loss: 0.0947 - accuracy: 0.9643 - precision: 0.9901 - recall: 0.9617 - val_loss: 0.1434 - val_accuracy: 0.9683 - val_precision: 0.9754 - val_recall: 0.9817
# Epoch 19/25
# 261/261 [==============================] - 48s 184ms/step - loss: 0.1136 - accuracy: 0.9547 - precision: 0.9893 - recall: 0.9496 - val_loss: 0.2318 - val_accuracy: 0.9029 - val_precision: 1.0000 - val_recall: 0.8681
# Epoch 20/25
# 261/261 [==============================] - 48s 184ms/step - loss: 0.0859 - accuracy: 0.9696 - precision: 0.9921 - recall: 0.9669 - val_loss: 0.1077 - val_accuracy: 0.9567 - val_precision: 0.9972 - val_recall: 0.9438
# Epoch 21/25
# 261/261 [==============================] - 48s 185ms/step - loss: 0.0752 - accuracy: 0.9729 - precision: 0.9937 - recall: 0.9697 - val_loss: 0.0805 - val_accuracy: 0.9731 - val_precision: 0.9973 - val_recall: 0.9660
# Epoch 22/25
# 261/261 [==============================] - 48s 184ms/step - loss: 0.0726 - accuracy: 0.9739 - precision: 0.9937 - recall: 0.9710 - val_loss: 0.0755 - val_accuracy: 0.9760 - val_precision: 0.9780 - val_recall: 0.9895
# Epoch 23/25
# 261/261 [==============================] - 48s 182ms/step - loss: 0.0881 - accuracy: 0.9713 - precision: 0.9927 - recall: 0.9685 - val_loss: 0.4814 - val_accuracy: 0.8683 - val_precision: 0.8506 - val_recall: 0.9961
# Epoch 24/25
# 261/261 [==============================] - 47s 181ms/step - loss: 0.0900 - accuracy: 0.9672 - precision: 0.9937 - recall: 0.9621 - val_loss: 0.0690 - val_accuracy: 0.9798 - val_precision: 0.9831 - val_recall: 0.9895
# Epoch 25/25
# 261/261 [==============================] - 47s 182ms/step - loss: 0.0714 - accuracy: 0.9751 - precision: 0.9925 - recall: 0.9740 - val_loss: 0.0720 - val_accuracy: 0.9769 - val_precision: 0.9973 - val_recall: 0.9713

# %%
# 결과확인

fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
# 모델평가

loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 4s 111ms/step - loss: 0.8784 - accuracy: 0.8285 - precision: 0.7942 - recall: 0.9795
# Loss: 0.8783766627311707,
# Accuracy: 0.8285256624221802,
# Precision: 0.7941787838935852,
# Recall: 0.9794871807098389

# %% [markdown]
# -----------------------------------------------------------------

# %% [markdown]
# ### 프로젝트 : 폐렴 진단기 성능개선

# %% [markdown]
# > 실험환경 Set-up

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미합니다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 64
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(f'train 개수: {len(train_filenames)}')
print(f'validation 개수 : {len(val_filenames)}')
print(f'test 개수 : {len(test_filenames)}')
# Out:
# train 개수: 5216
# validation 개수 : 16
# test 개수 : 624

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담는다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(f'train 개수: {len(train_filenames)}')
print(f'validation 개수 : {len(val_filenames)}')
print(f'test 개수 : {len(test_filenames)}')
# Out:
# train 개수: 4185
# validation 개수 : 1047
# test 개수 : 624

# %%
# 파일 경로
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/IM-0325-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/NORMAL2-IM-0409-0001.jpeg

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1093
# Pneumonia images count in training set: 3092

# %% [markdown]
# 데이터가 imbalance한 것은 차후에 조정할 예정이다.

# %%
# tf.data 인스턴스 생성

train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %% [markdown]
# 현재 이미지 데이터에는 라벨 데이터가 없으므로, 'NORMAL'이나 'PNEUMONIA'를 이용해서 라벨 데이터를 만들어 주는 함수를 만들자.

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지 사이즈 통일 및 사이즈 조절

# 이미지를 알맞은 형식으로 바꾼다
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어온다
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
# train 데이터 셋과 validation 데이터 셋 생성

train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
# 이미지 리사이즈, 라벨이 잘 들어가 있는지 확인

for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
# test 데이터셋도 만들기

test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

# test 데이터 개수 확인
print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# - Augmention

# %%
import tensorflow as tf
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),  # 좌우 반전
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.1),       # 회전
  tf.keras.layers.experimental.preprocessing.RandomZoom(-0.2,0.2),     # 확대/축소
  tf.keras.layers.experimental.preprocessing.RandomTranslation(height_factor=0.1, width_factor=0.1,
                                                               fill_mode='constant')  # 이미지 상하 이동
])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0])
    plt.axis("off")

# %% [markdown]
# - 데이터 시각화

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(5,math.ceil(BATCH_SIZE/5),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# - CNN 모델링

# %%
# 먼저, Convolution block을 만듭니다.
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
# Dense Block 만들기
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
# 모델생성
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        data_augmentation,  # 데이터 증강 레이어
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
#  - Weight balancing으로 데이터 imbalance 처리

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.91
# Weight for PNEUMONIA: 0.68

# %% [markdown]
# - 모델훈련

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 65/65 [==============================] - 56s 770ms/step - loss: 0.1517 - accuracy: 0.9404 - precision: 0.9816 - recall: 0.9369 - val_loss: 0.1363 - val_accuracy: 0.9521 - val_precision: 0.9561 - val_recall: 0.9820
# Epoch 2/25
# 65/65 [==============================] - 48s 742ms/step - loss: 0.1633 - accuracy: 0.9365 - precision: 0.9808 - recall: 0.9323 - val_loss: 0.3379 - val_accuracy: 0.8623 - val_precision: 0.9953 - val_recall: 0.8224
# Epoch 3/25
# 65/65 [==============================] - 49s 756ms/step - loss: 0.1626 - accuracy: 0.9361 - precision: 0.9835 - recall: 0.9291 - val_loss: 0.2711 - val_accuracy: 0.9043 - val_precision: 0.9927 - val_recall: 0.8802
# Epoch 4/25
# 65/65 [==============================] - 51s 788ms/step - loss: 0.1649 - accuracy: 0.9377 - precision: 0.9776 - recall: 0.9373 - val_loss: 0.7212 - val_accuracy: 0.7744 - val_precision: 1.0000 - val_recall: 0.7012
# Epoch 5/25
# 65/65 [==============================] - 51s 800ms/step - loss: 0.1574 - accuracy: 0.9368 - precision: 0.9795 - recall: 0.9337 - val_loss: 0.7346 - val_accuracy: 0.7529 - val_precision: 0.9981 - val_recall: 0.6736
# Epoch 6/25
# 65/65 [==============================] - 45s 697ms/step - loss: 0.1487 - accuracy: 0.9423 - precision: 0.9829 - recall: 0.9382 - val_loss: 0.1426 - val_accuracy: 0.9512 - val_precision: 0.9852 - val_recall: 0.9494
# Epoch 7/25
# 65/65 [==============================] - 45s 704ms/step - loss: 0.1608 - accuracy: 0.9329 - precision: 0.9772 - recall: 0.9312 - val_loss: 0.2164 - val_accuracy: 0.9229 - val_precision: 0.9874 - val_recall: 0.9098
# Epoch 8/25
# 65/65 [==============================] - 46s 709ms/step - loss: 0.1501 - accuracy: 0.9425 - precision: 0.9810 - recall: 0.9405 - val_loss: 0.2622 - val_accuracy: 0.9160 - val_precision: 0.9900 - val_recall: 0.8977
# Epoch 9/25
# 65/65 [==============================] - 45s 698ms/step - loss: 0.1492 - accuracy: 0.9380 - precision: 0.9798 - recall: 0.9351 - val_loss: 0.6145 - val_accuracy: 0.7783 - val_precision: 0.9982 - val_recall: 0.7069
# Epoch 10/25
# 65/65 [==============================] - 47s 723ms/step - loss: 0.1544 - accuracy: 0.9411 - precision: 0.9819 - recall: 0.9376 - val_loss: 0.4634 - val_accuracy: 0.8242 - val_precision: 0.9966 - val_recall: 0.7697
# Epoch 11/25
# 65/65 [==============================] - 47s 733ms/step - loss: 0.1489 - accuracy: 0.9450 - precision: 0.9853 - recall: 0.9395 - val_loss: 0.2634 - val_accuracy: 0.8945 - val_precision: 0.9955 - val_recall: 0.8645
# Epoch 12/25
# 65/65 [==============================] - 46s 720ms/step - loss: 0.1366 - accuracy: 0.9459 - precision: 0.9837 - recall: 0.9425 - val_loss: 0.4100 - val_accuracy: 0.8408 - val_precision: 0.9935 - val_recall: 0.7948
# Epoch 13/25
# 65/65 [==============================] - 45s 701ms/step - loss: 0.1502 - accuracy: 0.9401 - precision: 0.9806 - recall: 0.9375 - val_loss: 1.2177 - val_accuracy: 0.6289 - val_precision: 1.0000 - val_recall: 0.5097
# Epoch 14/25
# 65/65 [==============================] - 47s 722ms/step - loss: 0.1569 - accuracy: 0.9373 - precision: 0.9801 - recall: 0.9337 - val_loss: 0.2779 - val_accuracy: 0.8838 - val_precision: 0.9954 - val_recall: 0.8497
# Epoch 15/25
# 65/65 [==============================] - 47s 734ms/step - loss: 0.1418 - accuracy: 0.9409 - precision: 0.9821 - recall: 0.9376 - val_loss: 0.1341 - val_accuracy: 0.9541 - val_precision: 0.9597 - val_recall: 0.9807
# Epoch 16/25
# 65/65 [==============================] - 46s 716ms/step - loss: 0.1441 - accuracy: 0.9401 - precision: 0.9805 - recall: 0.9373 - val_loss: 0.3049 - val_accuracy: 0.8760 - val_precision: 0.9924 - val_recall: 0.8428
# Epoch 17/25
# 65/65 [==============================] - 46s 722ms/step - loss: 0.1427 - accuracy: 0.9411 - precision: 0.9842 - recall: 0.9352 - val_loss: 0.1559 - val_accuracy: 0.9346 - val_precision: 0.9707 - val_recall: 0.9419
# Epoch 18/25
# 65/65 [==============================] - 46s 717ms/step - loss: 0.1484 - accuracy: 0.9488 - precision: 0.9831 - recall: 0.9469 - val_loss: 0.9550 - val_accuracy: 0.6426 - val_precision: 1.0000 - val_recall: 0.5265
# Epoch 19/25
# 65/65 [==============================] - 46s 715ms/step - loss: 0.1482 - accuracy: 0.9428 - precision: 0.9827 - recall: 0.9393 - val_loss: 0.1663 - val_accuracy: 0.9365 - val_precision: 0.9903 - val_recall: 0.9251
# Epoch 20/25
# 65/65 [==============================] - 47s 725ms/step - loss: 0.1262 - accuracy: 0.9483 - precision: 0.9861 - recall: 0.9434 - val_loss: 0.1736 - val_accuracy: 0.9336 - val_precision: 0.9903 - val_recall: 0.9211
# Epoch 21/25
# 65/65 [==============================] - 46s 721ms/step - loss: 0.1399 - accuracy: 0.9421 - precision: 0.9849 - recall: 0.9358 - val_loss: 0.1273 - val_accuracy: 0.9531 - val_precision: 0.9573 - val_recall: 0.9820
# Epoch 22/25
# 65/65 [==============================] - 45s 706ms/step - loss: 0.1338 - accuracy: 0.9457 - precision: 0.9841 - recall: 0.9419 - val_loss: 0.8701 - val_accuracy: 0.7090 - val_precision: 0.9979 - val_recall: 0.6153
# Epoch 23/25
# 65/65 [==============================] - 47s 727ms/step - loss: 0.1237 - accuracy: 0.9505 - precision: 0.9857 - recall: 0.9465 - val_loss: 0.1544 - val_accuracy: 0.9482 - val_precision: 0.9865 - val_recall: 0.9444
# Epoch 24/25
# 65/65 [==============================] - 47s 724ms/step - loss: 0.1330 - accuracy: 0.9495 - precision: 0.9845 - recall: 0.9467 - val_loss: 0.1577 - val_accuracy: 0.9287 - val_precision: 0.9902 - val_recall: 0.9147
# Epoch 25/25
# 65/65 [==============================] - 46s 720ms/step - loss: 0.1276 - accuracy: 0.9505 - precision: 0.9874 - recall: 0.9448 - val_loss: 0.2650 - val_accuracy: 0.9141 - val_precision: 0.9957 - val_recall: 0.8905

# %% [markdown]
# - 결과확인

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# - 모델평가

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 10/10 [==============================] - 5s 473ms/step - loss: 0.2325 - accuracy: 0.9103 - precision: 0.9304 - recall: 0.9256
# Loss: 0.23249569535255432,
# Accuracy: 0.9102563858032227,
# Precision: 0.9304123520851135,
# Recall: 0.9256410002708435
